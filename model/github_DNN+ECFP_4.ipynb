# %%
import tensorflow as tf
from tensorflow.core import util
import keras
from keras import layers, models, utils, backend as K
from keras import regularizers
from keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import balanced_accuracy_score
from matplotlib import pyplot as plt

# %%
model = models.Sequential(name="DeepNN", layers=[
    # 1st hidden layer
    layers.Dense(name="h1", input_dim=1024, kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-1),
                 units=int(round((1024 * 1))),
                 activation='relu'),
    layers.Dropout(name="drop1", rate=0.4),
    # 2st hidden layer
    layers.Dense(name="h2", units=int(round((1024 * 0.7))),
                 activation='relu'),
    layers.Dropout(name="drop2", rate=0.7),
    # 3st hidden layer
    layers.Dense(name="h3", units=int(round((1024 * 0.35))),
                 activation='tanh'),
    layers.Dropout(name="drop3", rate=0.5),
    # final layer
    layers.Dense(name="output", units=1, activation='sigmoid')
])
model.summary()
# compiling Neural Networks
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3), loss='binary_crossentropy', metrics=['accuracy'])
# data loading
data = pd.read_csv(r'''D:\A309-21-\课题\DILI Predict\DILI数据+模型\汇总-DILI\train\RDKit-ECFP_4data.csv''', low_memory=False)
X = data.iloc[:,3:].values
y = data.loc[:,'DILIst.1'].values
# fixed random seed so that training is the same for each division, shuffle: reorder the data before splitting
BATCH_SIZE = 18
data_loader = DataLoader(dataset=data, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, drop_last=False)
dataset = data.sample(frac=1).reset_index(drop=True) 
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.33, random_state=42, shuffle=True)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=12)
class_weights = {0:1.521, 1:0.745}
# monitor: monitoring parameter, patience: exit if no boost in n-cycle, restore_best_weights: fetch optimal weights
EarlyStop = [EarlyStopping(monitor='val_loss', min_delta=0, patience=30, mode='min', verbose=1, restore_best_weights = True)]
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=500, batch_size=BATCH_SIZE, class_weight=class_weights, callbacks=EarlyStop, verbose=1, shuffle=True)

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)  # set the vertical range to [0-1]
plt.show()
# test
y_score_test = model.predict(X_test)
y_pred_test = (y_score_test > 0.5).astype("int32")
# model evaluation
TN, FP, FN, TP = confusion_matrix(y_test, y_pred_test).ravel()
SE = TP / (TP + FN)
SP = TN / (TN + FP)
ACC = (TP + TN) / (TP + TN + FP + FN)
F1 = 2 * (TP / (2 * TP + FN + FP))
MCC = (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))
AUC = roc_auc_score(y_test, y_score_test)
BA = balanced_accuracy_score(y_test, y_pred_test)
LR = pd.DataFrame({'SE': [SE], 'SP': [SP], 'ACC': [ACC], 'AUC': [AUC], 'F1': [F1], 'MCC': [MCC], 'BA': [BA]})
print(LR)
# Out:
# Model: "DeepNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 1024)              1049600
#
#  drop1 (Dropout)             (None, 1024)              0
#
#  h2 (Dense)                  (None, 717)               734925
#
#  drop2 (Dropout)             (None, 717)               0
#
#  h3 (Dense)                  (None, 358)               257044
#
#  drop3 (Dropout)             (None, 358)               0
#
#  output (Dense)              (None, 1)                 359
#
# =================================================================
# Total params: 2,041,928
# Trainable params: 2,041,928
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 59/59 [==============================] - 2s 30ms/step - loss: 29.0316 - accuracy: 0.5451 - val_loss: 2.0638 - val_accuracy: 0.6462
# Epoch 2/500
# 59/59 [==============================] - 2s 27ms/step - loss: 1.2472 - accuracy: 0.6068 - val_loss: 0.9379 - val_accuracy: 0.6577
# Epoch 3/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.9789 - accuracy: 0.6059 - val_loss: 1.0128 - val_accuracy: 0.4346
# Epoch 4/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.8666 - accuracy: 0.6420 - val_loss: 0.9795 - val_accuracy: 0.5077
# Epoch 5/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.8724 - accuracy: 0.6752 - val_loss: 0.9342 - val_accuracy: 0.5577
# Epoch 6/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.8211 - accuracy: 0.6990 - val_loss: 0.9240 - val_accuracy: 0.5846
# Epoch 7/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.8095 - accuracy: 0.7056 - val_loss: 0.9622 - val_accuracy: 0.6077
# Epoch 8/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.8156 - accuracy: 0.7265 - val_loss: 0.8964 - val_accuracy: 0.6423
# Epoch 9/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7707 - accuracy: 0.7407 - val_loss: 0.8834 - val_accuracy: 0.6500
# Epoch 10/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.7487 - accuracy: 0.7512 - val_loss: 0.8950 - val_accuracy: 0.6500
# Epoch 11/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7541 - accuracy: 0.7607 - val_loss: 0.8951 - val_accuracy: 0.6577
# Epoch 12/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7252 - accuracy: 0.7920 - val_loss: 0.9026 - val_accuracy: 0.6808
# Epoch 13/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7694 - accuracy: 0.7759 - val_loss: 0.8680 - val_accuracy: 0.6769
# Epoch 14/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6965 - accuracy: 0.7835 - val_loss: 0.9000 - val_accuracy: 0.6692
# Epoch 15/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7028 - accuracy: 0.7711 - val_loss: 0.8774 - val_accuracy: 0.7000
# Epoch 16/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.7016 - accuracy: 0.7911 - val_loss: 0.8984 - val_accuracy: 0.6923
# Epoch 17/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6900 - accuracy: 0.8091 - val_loss: 0.9518 - val_accuracy: 0.6538
# Epoch 18/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6566 - accuracy: 0.8253 - val_loss: 0.9751 - val_accuracy: 0.6654
# Epoch 19/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6559 - accuracy: 0.8357 - val_loss: 1.0229 - val_accuracy: 0.6346
# Epoch 20/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6555 - accuracy: 0.8234 - val_loss: 0.9661 - val_accuracy: 0.6769
# Epoch 21/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6567 - accuracy: 0.8272 - val_loss: 1.0334 - val_accuracy: 0.6423
# Epoch 22/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6869 - accuracy: 0.8034 - val_loss: 0.9483 - val_accuracy: 0.6692
# Epoch 23/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6556 - accuracy: 0.8300 - val_loss: 0.9860 - val_accuracy: 0.7000
# Epoch 24/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6697 - accuracy: 0.8205 - val_loss: 0.9941 - val_accuracy: 0.6769
# Epoch 25/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6502 - accuracy: 0.8281 - val_loss: 0.9685 - val_accuracy: 0.6654
# Epoch 26/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.6724 - accuracy: 0.8338 - val_loss: 1.0895 - val_accuracy: 0.6577
# Epoch 27/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6571 - accuracy: 0.8224 - val_loss: 1.0167 - val_accuracy: 0.6577
# Epoch 28/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6175 - accuracy: 0.8433 - val_loss: 1.0092 - val_accuracy: 0.6654
# Epoch 29/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6117 - accuracy: 0.8471 - val_loss: 0.9814 - val_accuracy: 0.6769
# Epoch 30/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6050 - accuracy: 0.8424 - val_loss: 0.9839 - val_accuracy: 0.6808
# Epoch 31/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6185 - accuracy: 0.8509 - val_loss: 1.0745 - val_accuracy: 0.6846
# Epoch 32/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6185 - accuracy: 0.8291 - val_loss: 1.0232 - val_accuracy: 0.7038
# Epoch 33/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6419 - accuracy: 0.8319 - val_loss: 1.0015 - val_accuracy: 0.6885
# Epoch 34/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6341 - accuracy: 0.8452 - val_loss: 1.0770 - val_accuracy: 0.6962
# Epoch 35/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6486 - accuracy: 0.8405 - val_loss: 1.0510 - val_accuracy: 0.6885
# Epoch 36/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6104 - accuracy: 0.8367 - val_loss: 1.0420 - val_accuracy: 0.6808
# Epoch 37/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.5713 - accuracy: 0.8414 - val_loss: 1.0795 - val_accuracy: 0.6808
# Epoch 38/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.5746 - accuracy: 0.8405 - val_loss: 0.9990 - val_accuracy: 0.6731
# Epoch 39/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.5906 - accuracy: 0.8547 - val_loss: 1.0676 - val_accuracy: 0.6692
# Epoch 40/500
# 59/59 [==============================] - 2s 27ms/step - loss: 0.5806 - accuracy: 0.8405 - val_loss: 1.0745 - val_accuracy: 0.6769
# Epoch 41/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.6032 - accuracy: 0.8272 - val_loss: 0.9613 - val_accuracy: 0.6692
# Epoch 42/500
# 59/59 [==============================] - 2s 28ms/step - loss: 0.5706 - accuracy: 0.8433 - val_loss: 1.0412 - val_accuracy: 0.6923
# Epoch 43/500
# 59/59 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.8414Restoring model weights from the end of the best epoch: 13.
# 59/59 [==============================] - 2s 28ms/step - loss: 0.5903 - accuracy: 0.8414 - val_loss: 1.0319 - val_accuracy: 0.6692
# Epoch 43: early stopping
# 9/9 [==============================] - 0s 6ms/step
#          SE        SP       ACC       AUC        F1       MCC        BA
# 0  0.723757  0.506329  0.657692  0.618715  0.746439  0.222432  0.615043
